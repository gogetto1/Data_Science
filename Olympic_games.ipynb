# %% [markdown]
# <a href="https://colab.research.google.com/github/gogetto1/Data_Science/blob/master/Olympic_games.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Import Dataset

# %%
from google.colab import files

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-86289405-479a-4bb3-8cea-5c39e2605ef6" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-86289405-479a-4bb3-8cea-5c39e2605ef6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# <ipython-input-21-ed2fd71b4a2f> in <module>()
# ----> 1 uploaded = files.upload()
#
# /usr/local/lib/python3.6/dist-packages/google/colab/files.py in upload()
#      62   result = _output.eval_js(
#      63       'google.colab._files._uploadFiles("{input_id}", "{output_id}")'.format(
# ---> 64           input_id=input_id, output_id=output_id))
# ...

# %%
import io
import pandas as pd

#df = pd.read_csv(io.BytesIO('athlete_events.csv'))

# %%
path = '/athlete_events.csv'
df = pd.read_csv(path)

# %%
df.head()
# Out:
#    ID                      Name  ...                             Event  Medal
# 0   1                 A Dijiang  ...       Basketball Men's Basketball    NaN
# 1   2                  A Lamusi  ...      Judo Men's Extra-Lightweight    NaN
# 2   3       Gunnar Nielsen Aaby  ...           Football Men's Football    NaN
# 3   4      Edgar Lindenau Aabye  ...       Tug-Of-War Men's Tug-Of-War   Gold
# 4   5  Christine Jacoba Aaftink  ...  Speed Skating Women's 500 metres    NaN
#
# [5 rows x 15 columns]

# %%
df.describe()
# Out:
#                   ID            Age  ...         Weight           Year
# count  271116.000000  261642.000000  ...  208241.000000  271116.000000
# mean    68248.954396      25.556898  ...      70.702393    1978.378480
# std     39022.286345       6.393561  ...      14.348020      29.877632
# min         1.000000      10.000000  ...      25.000000    1896.000000
# 25%     34643.000000      21.000000  ...      60.000000    1960.000000
# 50%     68205.000000      24.000000  ...      70.000000    1988.000000
# 75%    102097.250000      28.000000  ...      79.000000    2002.000000
# max    135571.000000      97.000000  ...     214.000000    2016.000000
#
# [8 rows x 5 columns]

# %%
df.query('Height > 0')
# Out:
#             ID  ... Medal
# 0            1  ...   NaN
# 1            2  ...   NaN
# 4            5  ...   NaN
# 5            5  ...   NaN
# 6            5  ...   NaN
# ...        ...  ...   ...
# 271111  135569  ...   NaN
# 271112  135570  ...   NaN
# 271113  135570  ...   NaN
# 271114  135571  ...   NaN
# 271115  135571  ...   NaN
#
# [210945 rows x 15 columns]

# %%
df.Medal.value_counts()
# Out:
# Gold      13372
# Bronze    13295
# Silver    13116
# Name: Medal, dtype: int64

# %%
df[df['Medal'].notnull()]
# Out:
#             ID  ...   Medal
# 3            4  ...    Gold
# 37          15  ...  Bronze
# 38          15  ...  Bronze
# 40          16  ...  Bronze
# 41          17  ...  Bronze
# ...        ...  ...     ...
# 271078  135553  ...  Silver
# 271080  135553  ...  Bronze
# 271082  135554  ...  Bronze
# 271102  135563  ...  Bronze
# 271103  135563  ...  Silver
#
# [39783 rows x 15 columns]

# %% [markdown]
# #Seaborn visualization library

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
sns.relplot(data=df, y='Age', x='Medal', hue='Season', col='Sex')

# %%
sns.set(style="ticks")
sns.relplot(data=df, y='Age', x='Sex', hue='Season', col='Medal')

# %%
sns.regplot(data=df.query('Medal == "Gold" & Year > 1980'), x='Year', y='Age',
            x_estimator=np.mean)

# %% [markdown]
# ##Value

# %%
fig = df.Sex.value_counts().plot(kind='pie',
                           shadow=True,
                           labels=['Men', 'Female'],
                           autopct='%1.1f%%',
                           explode=[0.1, 0.0],
                           figsize=(8,8),
                           fontsize=18,
                           legend=True
                        )
plt.title('Sex \n Distribution', size = 25)
plt.ylabel('Sex', size = 18)
plt.legend(loc=1, fontsize=14)

# %% [markdown]
# ##Height to weight of medalist at 1980.

# %%
df.head(2)
# Out:
#    ID       Name Sex  ...       Sport                         Event  Medal
# 0   1  A Dijiang   M  ...  Basketball   Basketball Men's Basketball    NaN
# 1   2   A Lamusi   M  ...        Judo  Judo Men's Extra-Lightweight    NaN
#
# [2 rows x 15 columns]

# %%
sns.regplot(data=df.query('Medal == ["Bronze","Silver","Gold"] & Year > 1980'), x='Height', y='Weight',
            x_estimator=np.mean)

# %%
sns.relplot(data=df.query('Medal == "Gold" & Year > 1980'), x='Height', y='Weight',
            hue='Sex',row='Year'
           )

# %%
df.describe(include=['object'])
# Out:
#                         Name     Sex  ...                    Event  Medal
# count                 271116  271116  ...                   271116  39783
# unique                134732       2  ...                      765      3
# top     Robert Tait McKenzie       M  ...  Football Men's Football   Gold
# freq                      58  196594  ...                     5733  13372
#
# [4 rows x 10 columns]

# %%
df = df.query('Medal == ["Bronze","Silver","Gold"] & Year > 1990')

# %%
df.head()
# Out:
#     ID                      Name  ...                             Event   Medal
# 40  16  Juhamatti Tapio Aaltonen  ...       Ice Hockey Men's Ice Hockey  Bronze
# 60  20        Kjetil Andr Aamodt  ...       Alpine Skiing Men's Super G    Gold
# 61  20        Kjetil Andr Aamodt  ...  Alpine Skiing Men's Giant Slalom  Bronze
# 63  20        Kjetil Andr Aamodt  ...      Alpine Skiing Men's Downhill  Silver
# 64  20        Kjetil Andr Aamodt  ...       Alpine Skiing Men's Super G  Bronze
#
# [5 rows x 15 columns]

# %%
df.describe()
# Out:
#                   ID           Age        Height        Weight          Year
# count   16781.000000  16781.000000  16454.000000  16373.000000  16781.000000
# mean    70352.281390     25.962458    177.766926     73.777520   2004.245516
# std     39129.654971      5.016744     11.379891     15.723181      7.800173
# min        16.000000     13.000000    136.000000     28.000000   1992.000000
# 25%     37496.000000     22.000000    170.000000     62.000000   1996.000000
# 50%     69549.000000     25.000000    178.000000     72.000000   2004.000000
# 75%    104550.000000     29.000000    185.000000     84.000000   2012.000000
# max    135563.000000     61.000000    223.000000    175.000000   2016.000000

# %%
df.describe(include=['object'])
# Out:
#                            Name    Sex  ...                        Event   Medal
# count                     16781  16781  ...                        16781   16781
# unique                    11643      2  ...                          467       3
# top     Michael Fred Phelps, II      M  ...  Ice Hockey Men's Ice Hockey  Bronze
# freq                         28   9499  ...                          470    5753
#
# [4 rows x 10 columns]
